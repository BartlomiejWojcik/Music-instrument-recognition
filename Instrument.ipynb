# %%
import librosa
import librosa.display
import matplotlib.pyplot as plt
import numpy as np

audio_path = 'IRMAS-TrainingData\cla\[cla][cla]0152__1.wav'
x , sr = librosa.load(audio_path)

# %%
import IPython.display as ipd
ipd.Audio(audio_path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
sr
# Out:
# 22050

# %%
hop_length = 512
n_mels = 128
n_fft = 2048

# %%
S = librosa.feature.melspectrogram(x, sr=sr, n_fft=n_fft, hop_length=hop_length, n_mels=n_mels)
S_DB = librosa.power_to_db(S, ref=np.max)

librosa.display.specshow(S_DB, sr=sr, hop_length=hop_length, x_axis='time', y_axis='mel');
plt.colorbar(format='%+2.00f dB');

# %%
S
# Out:
# array([[1.00921278e-01, 3.55498184e-02, 6.67483302e-03, ...,
#         2.52846638e-03, 7.48375670e-03, 3.52380651e-02],
#        [5.34408976e-02, 3.29540817e-02, 2.13939774e-02, ...,
#         7.84178621e-03, 1.11166352e-02, 1.29656352e-02],
#        [1.45300605e-01, 6.01017924e-02, 4.45228207e-02, ...,
#         2.62822027e-02, 5.87959982e-02, 8.20009176e-02],
#        ...,
#        [1.01123713e-03, 2.63332536e-04, 1.74005096e-05, ...,
#         1.05936134e-08, 8.75266047e-05, 6.90551444e-04],
#        [1.71934480e-03, 4.30556257e-04, 1.01245211e-06, ...,
#         1.37062728e-08, 1.07557566e-04, 8.48465608e-04],
#        [1.95560462e-03, 4.88931352e-04, 6.33953101e-09, ...,
#         5.82760134e-10, 1.15905171e-04, 9.14412751e-04]])
